# %% [markdown]
# > ### Collection expressions
# >    Version *C# 12.0*  and available with .NET8.0 SDK

# %% [markdown]
# > **Collection expressions**: "Collection expressions" is a new feature introduced in C# 12 that allows for the creation of common collection values using a new terse syntax, [e1, e2, e3, etc].
# >
# >  - This syntax can be used to inline other collections into these values using a spread operator .. like so: [e1, ..c2, e2, ..c2].
#
# > This is preview -5  feature
#
# ```c#
#     // Example 1: Creating an array of integers
#
#     int[] numbers = [1, 2, 3, 4, 5];
# ```
#
# ```c#
#     // Example 2: Creating a list of strings
#     List<string> fruits = ["apple", "banana", "cherry"];
# ```
#
# ```c#
#     // Example 3:Create a span
#     Span<char> c  = ['a', 'b', 'c', 'd', 'e', 'f', 'h', 'i'];
# ```
#
# ```c#
#     // Example 4:Create a jagged 2D array:
#     int[][] twoD = [[1, 2, 3], [4, 5, 6], [7, 8, 9]];
# ```
#
# ```c#
#     // Example 5:Create a jagged 2D array from variables:
#     int[] row0 = [2, 4, 6];
#     int[] row1 = [3, 6, 9];
#     int[] row2 = [4, 8, 12];
#     int[][] twoDFromVariables = [row0, row1, row2];
# ```

# %%
    // Example 1: Creating an array of integers

    //int[] numbers =new int[] {1,2,3,4,5};
    
    int[] numbers = [1, 2, 3, 4, 5];
     display(numbers);
# Out:
# <div class="dni-plaintext"><pre>[ 1, 2, 3, 4, 5 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
 //int[] x2 = Array.Empty<int>();
    int[] x2 =[];
    display(x2);
# Out:
# <div class="dni-plaintext"><pre>[  ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
// Example 2: Creating a list of strings
    //List<int> x4 = new() { 1, 2, 3, 4 };
    List<int> x4 =[ 1, 2, 3, 4 ];
    display(x4);
    List<string> fruits = ["apple", "banana", "cherry"];
     display(fruits);
# Out:
# <div class="dni-plaintext"><pre>[ 1, 2, 3, 4 ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>
# <div class="dni-plaintext"><pre>[ apple, banana, cherry ]</pre></div><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
    // Example 3:Create a span
    // Span<char> c  = ['a', 'b', 'c', 'd', 'e', 'f', 'h', 'i'];

# %%
// Example 4:Create a jagged 2D array:
    int[][] twoD = [[1, 2, 3], [4, 5, 6], [7, 8, 9]];
    display(twoD);
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext"><pre>[ 1, 2, 3 ]</pre></div></td></tr><tr><td>1</td><td><div class="dni-plaintext"><pre>[ 4, 5, 6 ]</pre></div></td></tr><tr><td>2</td><td><div class="dni-plaintext"><pre>[ 7, 8, 9 ]</pre></div></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %%
 // Example 5:Create a jagged 2D array from variables:
    int[] row0 = [2, 4, 6];
    int[] row1 = [3, 6, 9];
    int[] row2 = [4, 8, 12,14];
    int[][] twoDFromVariables = [row0, row1, row2];
    display(twoDFromVariables);
# Out:
# <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext"><pre>[ 2, 4, 6 ]</pre></div></td></tr><tr><td>1</td><td><div class="dni-plaintext"><pre>[ 3, 6, 9 ]</pre></div></td></tr><tr><td>2</td><td><div class="dni-plaintext"><pre>[ 4, 8, 12, 14 ]</pre></div></td></tr></tbody></table><style>
# .dni-code-hint {
#     font-style: italic;
#     overflow: hidden;
#     white-space: nowrap;
# }
# .dni-treeview {
#     white-space: nowrap;
# }
# .dni-treeview td {
#     vertical-align: top;
#     text-align: start;
# }
# details.dni-treeview {
#     padding-left: 1em;
# }
# table td {
#     text-align: start;
# }
# table tr {
#     vertical-align: top;
#     margin: 0em 0px;
# }
# table tr td pre
# {
#     vertical-align: top !important;
#     margin: 0em 0px !important;
# }
# table th {
#     text-align: start;
# }
# </style>

# %% [markdown]
# # Continue learning
#
# There are plenty more resources out there to learn!
#
# > [⏩ Next Module - Inline Arrays ](101.InlineArrays.ipynb)
# >
# > [⏪ Last Module - Primart Constructors](99.PrimartConstructors.ipynb)
# >
# > [Reference- Collection-expressions](https://learn.microsoft.com/en-us/dotnet/csharp/whats-new/csharp-12#collection-expressions)
# >
# > [Reference- C# 12 Version](https://learn.microsoft.com/en-us/dotnet/csharp/whats-new/csharp-12)
