# %% [markdown]
# 1. Git graph using Mermaid

# %%
# %%{init: { 'logLevel': 'debug', 'theme': 'base', 'gitGraph': {'showBranches': false}} }%%
#       gitGraph
#         commit
#         branch hotfix
#         checkout hotfix
#         commit
#         branch develop
#         checkout develop
#         commit id:"ash" tag:"abc"
#         branch featureB
#         checkout featureB
#         commit type:HIGHLIGHT
#         checkout main
#         checkout hotfix
#         commit type:NORMAL
#         checkout develop
#         commit type:REVERSE
#         checkout featureB
#         commit
#         checkout main
#         merge hotfix
#         checkout featureB
#         commit
#         checkout develop
#         branch featureA
#         commit
#         checkout develop
#         merge hotfix
#         checkout featureA
#         commit
#         checkout featureB
#         commit
#         checkout develop
#         merge featureA
#         branch release
#         checkout release
#         commit
#         checkout main
#         commit
#         checkout release
#         merge main
#         checkout develop
#         merge release
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="2bd168a7576b48e788173f96d343eb30"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('2bd168a7576b48e788173f96d343eb30');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_2bd168a7576b48e788173f96d343eb30',
#                     `%%{init: { 'logLevel': 'debug', 'theme': 'base', 'gitGraph': {'showBranches': false}} }%%
#       gitGraph
#         commit
#         branch hotfix
#         checkout hotfix
#         commit
#         branch develop
#         checkout develop
#         commit id:"ash" tag:"abc"
#         branch featureB
#         checkout featureB
#         commit type:HIGHLIGHT
#         checkout main
#         checkout hotfix
#         commit type:NORMAL
#         checkout develop
#         commit type:REVERSE
#         checkout featureB
#         commit
#         checkout main
#         merge hotfix
#         checkout featureB
#         commit
#         checkout develop
#         branch featureA
#         commit
#         checkout develop
#         merge hotfix
#         checkout featureA
#         commit
#         checkout featureB
#         commit
#         checkout develop
#         merge featureA
#         branch release
#         checkout release
#         commit
#         checkout main
#         commit
#         checkout release
#         merge main
#         checkout develop
#         merge release`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# 2.State Diagram using Mermaid

# %%
stateDiagram-v2
    [*] --> Active

    state Active {
        [*] --> NumLockOff
        NumLockOff --> NumLockOn : EvNumLockPressed
        NumLockOn --> NumLockOff : EvNumLockPressed
        --
        [*] --> CapsLockOff
        CapsLockOff --> CapsLockOn : EvCapsLockPressed
        CapsLockOn --> CapsLockOff : EvCapsLockPressed
        --
        [*] --> ScrollLockOff
        ScrollLockOff --> ScrollLockOn : EvScrollLockPressed
        ScrollLockOn --> ScrollLockOff : EvScrollLockPressed
    }
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="ac8b6ef1e2f641ac930a363bab888f1d"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('ac8b6ef1e2f641ac930a363bab888f1d');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_ac8b6ef1e2f641ac930a363bab888f1d',
#                     `stateDiagram-v2
#     [*] --> Active
#
#     state Active {
#         [*] --> NumLockOff
#         NumLockOff --> NumLockOn : EvNumLockPressed
#         NumLockOn --> NumLockOff : EvNumLockPressed
#         --
#         [*] --> CapsLockOff
#         CapsLockOff --> CapsLockOn : EvCapsLockPressed
#         CapsLockOn --> CapsLockOff : EvCapsLockPressed
#         --
#         [*] --> ScrollLockOff
#         ScrollLockOff --> ScrollLockOn : EvScrollLockPressed
#         ScrollLockOn --> ScrollLockOff : EvScrollLockPressed
#     }`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# 3.stateDiagram using Mermaid

# %%
stateDiagram-v2
state fork_state <<fork>>
  [*] --> fork_state
  fork_state --> State2
  fork_state --> State3

  state join_state <<join>>
  State2 --> join_state
  State3 --> join_state
  join_state --> State4
  State4 --> [*]
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="15f8d31d8817412382b02492440219c3"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('15f8d31d8817412382b02492440219c3');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_15f8d31d8817412382b02492440219c3',
#                     `stateDiagram-v2
# state fork_state <<fork>>
#   [*] --> fork_state
#   fork_state --> State2
#   fork_state --> State3
#
#   state join_state <<join>>
#   State2 --> join_state
#   State3 --> join_state
#   join_state --> State4
#   State4 --> [*]`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %% [markdown]
# 4.graph using Mermaid

# %%
graph TB
    sq[Square shape] --> ci((Circle shape))

    subgraph A
        od>Odd shape]-- Two line<br/>edge comment --> ro
        di{Diamond with <br/> line break} -.-> ro(Rounded<br>square<br>shape)
        di==>ro2(Rounded square shape)
    end

    %% Notice that no text in shape are added here instead that is appended further down
    e --> od3>Really long text with linebreak<br>in an Odd shape]

    %% Comments after double percent signs
    e((Inner / circle<br>and some odd <br>special characters)) --> f(,.?!+-*ز)

    cyr[Cyrillic]-->cyr2((Circle shape Начало));

     classDef green fill:#9f6,stroke:#333,stroke-width:2px;
     classDef orange fill:#f96,stroke:#333,stroke-width:4px;
     class sq,e green
     class di orange
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="942b3145fb1142819a6ff1cbecbd360b"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('942b3145fb1142819a6ff1cbecbd360b');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_942b3145fb1142819a6ff1cbecbd360b',
#                     `graph TB
#     sq[Square shape] --> ci((Circle shape))
#
#     subgraph A
#         od>Odd shape]-- Two line<br/>edge comment --> ro
#         di{Diamond with <br/> line break} -.-> ro(Rounded<br>square<br>shape)
#         di==>ro2(Rounded square shape)
#     end
#
#     %% Notice that no text in shape are added here instead that is appended further down
#     e --> od3>Really long text with linebreak<br>in an Odd shape]
#
#     %% Comments after double percent signs
#     e((Inner / circle<br>and some odd <br>special characters)) --> f(,.?!+-*ز)
#
#     cyr[Cyrillic]-->cyr2((Circle shape Начало));
#
#      classDef green fill:#9f6,stroke:#333,stroke-width:2px;
#      classDef orange fill:#f96,stroke:#333,stroke-width:4px;
#      class sq,e green
#      class di orange`);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>

# %%
gantt
dateFormat  YYYY-MM-DD
title Adding GANTT diagram to mermaid
excludes weekdays 2014-01-10

section A section
Completed task            :done,    des1, 2014-01-06,2014-01-08
Active task               :active,  des2, 2014-01-09, 3d
Future task               :         des3, after des2, 5d
Future task2               :         des4, after des1, 5d
# Out:
# <div class="mermaidMarkdownContainer" style="background-color:white">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
# <div id="7bade0d34fad4d5d8ce761c3ff335f89"></div>
# <script type="module">
#
#             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
#             let renderTarget = document.getElementById('7bade0d34fad4d5d8ce761c3ff335f89');
#             try {
#                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
#                     'mermaid_7bade0d34fad4d5d8ce761c3ff335f89',
#                     `gantt
# dateFormat  YYYY-MM-DD
# title Adding GANTT diagram to mermaid
# excludes weekdays 2014-01-10
#
# section A section
# Completed task            :done,    des1, 2014-01-06,2014-01-08
# Active task               :active,  des2, 2014-01-09, 3d
# Future task               :         des3, after des2, 5d
# Future task2               :         des4, after des1, 5d
# `);
#                 renderTarget.innerHTML = svg;
#                 bindFunctions?.(renderTarget);
#             }
#             catch (error) {
#                 console.log(error);
#             }
# </script>
# </div>
